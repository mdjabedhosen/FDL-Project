# %% [markdown]
# # CIFAR-10 Preprocessing (TensorFlow Version)
# - Full dataset: 50K train + 10K test
# - Denoising → CLAHE → Sharpening on original 32×32
# - Data Augmentation: 50K → 75K images
# - Augmentations: Flip + Rotation + Crop + Brightness + Cutout

# %%
# %pip install scipy numpy matplotlib pillow scikit-learn opencv-python tensorflow
# Out:
# Requirement already satisfied: scipy in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (1.17.1)
# Requirement already satisfied: numpy in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (2.4.4)
# Requirement already satisfied: matplotlib in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (3.10.9)
# Requirement already satisfied: pillow in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (12.2.0)
# Requirement already satisfied: scikit-learn in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: opencv-python in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (4.13.0.92)
# Requirement already satisfied: tensorflow in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (2.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pyparsing>=3 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.3.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (81.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/mjabed3834/Downloads/IndustryBiscuit/.conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. Load Full Dataset (50K + 10K)

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import os

if os.path.basename(os.getcwd()) == 'Preprocessing':
    os.chdir('..')
if os.path.basename(os.getcwd()) == 'TensorFlow':
    os.chdir('..')

DATA_DIR = 'Dataset'

meta = scipy.io.loadmat(os.path.join(DATA_DIR, 'batches.meta.mat'))
label_names = [name[0] for name in meta['label_names'].flatten()]
print('Classes:', label_names)

train_data, train_labels = [], []
for i in range(1, 6):
    batch = scipy.io.loadmat(os.path.join(DATA_DIR, f'data_batch_{i}.mat'))
    train_data.append(batch['data'])
    train_labels.append(batch['labels'].flatten())

train_data = np.concatenate(train_data).reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1).astype(np.uint8)
train_labels = np.concatenate(train_labels)

test_batch = scipy.io.loadmat(os.path.join(DATA_DIR, 'test_batch.mat'))
test_data = test_batch['data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1).astype(np.uint8)
test_labels = test_batch['labels'].flatten()

print(f'Train: {train_data.shape} | Test: {test_data.shape}')
# Out:
# Classes: [np.str_('airplane'), np.str_('automobile'), np.str_('bird'), np.str_('cat'), np.str_('deer'), np.str_('dog'), np.str_('frog'), np.str_('horse'), np.str_('ship'), np.str_('truck')]
# Train: (50000, 32, 32, 3) | Test: (10000, 32, 32, 3)

# %% [markdown]
# ## 2. Denoising → CLAHE → Sharpening

# %%
def preprocess_image(img):
    denoised = cv2.GaussianBlur(img, (3, 3), 0.5)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(4, 4))
    channels = cv2.split(denoised)
    clahe_channels = [clahe.apply(ch) for ch in channels]
    clahe_img = cv2.merge(clahe_channels)
    blurred = cv2.GaussianBlur(clahe_img, (3, 3), 1.0)
    sharpened = cv2.addWeighted(clahe_img, 1.5, blurred, -0.5, 0)
    return sharpened

def preprocess_batch(images, name=''):
    processed = np.zeros_like(images)
    for i in range(len(images)):
        processed[i] = preprocess_image(images[i])
        if (i + 1) % 10000 == 0:
            print(f'  {name} Processed {i + 1}/{len(images)}')
    return processed

print('Preprocessing training images (50K)...')
train_processed = preprocess_batch(train_data, 'Train:')
print('Preprocessing test images (10K)...')
test_processed = preprocess_batch(test_data, 'Test:')
print('Done!')
# Out:
# Preprocessing training images (50K)...
#   Train: Processed 10000/50000
#   Train: Processed 20000/50000
#   Train: Processed 30000/50000
#   Train: Processed 40000/50000
#   Train: Processed 50000/50000
# Preprocessing test images (10K)...
#   Test: Processed 10000/10000
# Done!

# %% [markdown]
# ## 3. Before vs After Comparison

# %%
np.random.seed(42)
sample_idx = np.random.choice(len(train_data), 10, replace=False)

fig, axes = plt.subplots(2, 10, figsize=(20, 5))
fig.suptitle('Before vs After (Denoise + CLAHE + Sharpen)', fontsize=14, fontweight='bold')
for i, idx in enumerate(sample_idx):
    axes[0, i].imshow(train_data[idx]); axes[0, i].axis('off')
    axes[0, i].set_title(f'{label_names[train_labels[idx]]}\nOriginal', fontsize=8)
    axes[1, i].imshow(train_processed[idx]); axes[1, i].axis('off')
    axes[1, i].set_title('Processed', fontsize=8)
plt.tight_layout()
plt.savefig('TensorFlow/Figure/before_after.png', dpi=150)
plt.show()

# %% [markdown]
# ## 4. Data Augmentation (50K → 75K)

# %%
def cutout(img, size=8):
    h, w = img.shape[:2]
    y = np.random.randint(0, h)
    x = np.random.randint(0, w)
    y1 = max(0, y - size // 2)
    y2 = min(h, y + size // 2)
    x1 = max(0, x - size // 2)
    x2 = min(w, x + size // 2)
    result = img.copy()
    result[y1:y2, x1:x2] = 0
    return result

def augment_image(img):
    aug = img.copy()
    if np.random.random() > 0.5:
        aug = np.fliplr(aug)
    angle = np.random.uniform(-15, 15)
    h, w = aug.shape[:2]
    M = cv2.getRotationMatrix2D((w/2, h/2), angle, 1.0)
    aug = cv2.warpAffine(aug, M, (w, h), borderMode=cv2.BORDER_REFLECT)
    padded = np.pad(aug, ((4, 4), (4, 4), (0, 0)), mode='reflect')
    x = np.random.randint(0, 8)
    y = np.random.randint(0, 8)
    aug = padded[y:y+32, x:x+32]
    factor = np.random.uniform(0.8, 1.2)
    aug = np.clip(aug * factor, 0, 255).astype(np.uint8)
    if np.random.random() > 0.5:
        aug = cutout(aug, size=10)
    return aug

NUM_AUGMENTED = 25000
np.random.seed(42)
samples_per_class = NUM_AUGMENTED // 10

aug_images, aug_labels = [], []
for cls in range(10):
    cls_indices = np.where(train_labels == cls)[0]
    chosen = np.random.choice(cls_indices, samples_per_class, replace=True)
    for idx in chosen:
        aug_images.append(augment_image(train_processed[idx]))
        aug_labels.append(cls)
    print(f'  Augmented {label_names[cls]}: {samples_per_class} images')

aug_images = np.array(aug_images)
aug_labels = np.array(aug_labels)

train_final = np.concatenate([train_processed, aug_images])
labels_final = np.concatenate([train_labels, aug_labels])

shuffle_idx = np.random.permutation(len(train_final))
train_final = train_final[shuffle_idx]
labels_final = labels_final[shuffle_idx]

print(f'\nOriginal:  {train_processed.shape[0]:,} images')
print(f'Augmented: {aug_images.shape[0]:,} images')
print(f'Total:     {train_final.shape[0]:,} images')
# Out:
#   Augmented airplane: 2500 images
#   Augmented automobile: 2500 images
#   Augmented bird: 2500 images
#   Augmented cat: 2500 images
#   Augmented deer: 2500 images
#   Augmented dog: 2500 images
#   Augmented frog: 2500 images
#   Augmented horse: 2500 images
#   Augmented ship: 2500 images
#   Augmented truck: 2500 images
#
# Original:  50,000 images
# Augmented: 25,000 images
# Total:     75,000 images

# %% [markdown]
# ## 5. Show Augmented Samples

# %%
fig, axes = plt.subplots(3, 10, figsize=(20, 7))
fig.suptitle('Original → Processed → Augmented', fontsize=14, fontweight='bold')
np.random.seed(99)
for i in range(10):
    idx = np.random.choice(np.where(train_labels == i)[0])
    axes[0, i].imshow(train_data[idx]); axes[0, i].axis('off')
    axes[0, i].set_title(f'{label_names[i]}\nOriginal', fontsize=8)
    axes[1, i].imshow(train_processed[idx]); axes[1, i].axis('off')
    axes[1, i].set_title('Processed', fontsize=8)
    axes[2, i].imshow(augment_image(train_processed[idx])); axes[2, i].axis('off')
    axes[2, i].set_title('Augmented', fontsize=8)
plt.tight_layout()
plt.savefig('TensorFlow/Figure/augmentation_samples.png', dpi=150)
plt.show()

# %% [markdown]
# ## 6. Class Distribution

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4))
for ax, labels, title in zip(axes, [train_labels, labels_final], ['Original (50K)', 'After Augmentation (75K)']):
    counts = np.bincount(labels)
    ax.bar(range(10), counts, color='steelblue')
    ax.set_xticks(range(10)); ax.set_xticklabels(label_names, rotation=45, ha='right')
    ax.set_ylabel('Count'); ax.set_title(title)
    for j, c in enumerate(counts):
        ax.text(j, c + 50, str(c), ha='center', fontsize=8)
plt.tight_layout()
plt.savefig('TensorFlow/Figure/class_distribution.png', dpi=150)
plt.show()

# %% [markdown]
# ## 7. Normalize & Standardize

# %%
train_norm = train_final.astype(np.float32) / 255.0
test_norm = test_processed.astype(np.float32) / 255.0

channel_mean = train_norm.mean(axis=(0, 1, 2))
channel_std = train_norm.std(axis=(0, 1, 2))
print(f'Channel means (R,G,B): {channel_mean}')
print(f'Channel stds  (R,G,B): {channel_std}')

train_std = (train_norm - channel_mean) / channel_std
test_std = (test_norm - channel_mean) / channel_std

print(f'\nTrain - min: {train_std.min():.3f}, max: {train_std.max():.3f}, mean: {train_std.mean():.6f}')
print(f'Test  - min: {test_std.min():.3f}, max: {test_std.max():.3f}, mean: {test_std.mean():.6f}')
# Out:
# Channel means (R,G,B): [0.21845333 0.21845333 0.21845333]
# Channel stds  (R,G,B): [0.3503174  0.34963942 0.34616226]
#
# Train - min: -0.631, max: 2.258, mean: 0.836690
# Test  - min: -0.631, max: 2.258, mean: 0.866225

# %% [markdown]
# ## 8. Train / Validation Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    train_std, labels_final,
    test_size=0.1, random_state=42, stratify=labels_final
)

X_test = test_std
y_test = test_labels

print(f'Training set:   {X_train.shape} | Labels: {y_train.shape}')
print(f'Validation set: {X_val.shape}  | Labels: {y_val.shape}')
print(f'Test set:       {X_test.shape} | Labels: {y_test.shape}')
# Out:
# Training set:   (67500, 32, 32, 3) | Labels: (67500,)
# Validation set: (7500, 32, 32, 3)  | Labels: (7500,)
# Test set:       (10000, 32, 32, 3) | Labels: (10000,)

# %% [markdown]
# ## 9. Save Preprocessed Data

# %%
out_path = 'TensorFlow/Preprocessing/cifar10_preprocessed.npz'
np.savez_compressed(out_path,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    X_test=X_test, y_test=y_test,
    channel_mean=channel_mean, channel_std=channel_std,
    label_names=label_names
)
print(f'Saved: {out_path} ({os.path.getsize(out_path) / (1024**2):.1f} MB)')
# Out:
# Saved: TensorFlow/Preprocessing/cifar10_preprocessed.npz (381.8 MB)

# %% [markdown]
# ## Summary
#
# | Step | Details |
# |---|---|
# | Dataset | **Full: 50K train + 10K test** |
# | Resolution | Original 32×32 |
# | Denoising | Gaussian blur (3×3, σ=0.5) |
# | Contrast | CLAHE (clipLimit=2.0, tile=4×4) |
# | Sharpening | Unsharp masking (1.5x) |
# | Augmentation | Flip + Rotation + Crop + Brightness + **Cutout** |
# | Total images | **75K** (50K original + 25K augmented) |
# | Normalize | Per-channel standardize |
# | Split | **67.5K train / 7.5K val / 10K test** |
